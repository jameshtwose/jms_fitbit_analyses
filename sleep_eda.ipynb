# %% [markdown]
# ## Sleep Exploratory Data Analysis

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import session_info
from utils import apply_scaling

from jmspack.NLTSA import (ts_levels, 
                           distribution_uniformity, 
                           fluctuation_intensity, 
                           complexity_resonance, 
                           complexity_resonance_diagram,
                          cumulative_complexity_peaks,
                          cumulative_complexity_peaks_plot)

from sklearn.preprocessing import MinMaxScaler, StandardScaler, MaxAbsScaler

# %%
session_info.show(write_req_file=False)
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# matplotlib          3.3.4
# pandas              1.2.3
# seaborn             0.11.1
# session_info        1.0.0
# sklearn             0.24.1
# utils               NA
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                 8.1.2
# appnope             0.1.2
# backcall            0.2.0
# cffi                1.14.5
# colorama            0.4.4
# cycler              0.10.0
# cython_runtime      NA
# dateutil            2.8.1
# decorator           4.4.2
# ipykernel           5.3.4
# ipython_genutils    0.2.0
# ipywidgets          7.6.3
# jedi                0.17.2
# joblib              0.17.0
# kiwisolver          1.3.1
# mpl_toolkits        NA
# numpy               1.19.2
# parso               0.7.0
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# prompt_toolkit      3.0.8
# ptyprocess          0.7.0
# pyexpat             NA
# pygments            2.8.1
# pyparsing           2.4.7
# pytz                2021.1
# scipy               1.5.3
# six                 1.15.0
# statsmodels         0.12.2
# storemagic          NA
# tornado             6.1
# traitlets           5.0.5
# wcwidth             0.2.5
# zmq                 20.0.0
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             7.21.0
# jupyter_client      6.1.7
# jupyter_core        4.7.1
# jupyterlab          2.2.6
# notebook            6.2.0
# -----
# Python 3.9.2 (default, Mar  3 2021, 11:58:52) [Clang 10.0.0 ]
# macOS-10.16-x86_64-i386-64bit
# -----
# Session information updated at 2021-07-19 15:41
# </pre>
# </details>

# %%
current_wd = os.getcwd()

# %%
os.chdir(current_wd + "/MyFitbitData/JamesTwose/")

# %%
df = pd.read_csv("Sleep/sleep_score.csv")

# %%
os.chdir(current_wd)

# %%
df = (df
 .assign(timestamp = lambda d: pd.to_datetime(d["timestamp"]))
 .assign(date = lambda d: pd.to_datetime(d["timestamp"]).dt.round("d").dt.date)
 .drop(["timestamp", "sleep_log_entry_id"], axis=1)
 .sort_values("date")
 .set_index("date")
)

# %% [markdown]
# ## Raw data heatmap

# %%
_ = plt.figure(figsize=(20, 5))
_ = sns.heatmap(data = df.T)

# %% [markdown]
# ## Scaled data heatmap

# %%
_ = plt.figure(figsize=(20, 5))
_ = sns.heatmap(df
                .pipe(apply_scaling)
                .T
               )

# %%
fi_df = fluctuation_intensity(df=df.pipe(apply_scaling), 
                      win=7, 
                      xmin=0, 
                      xmax=1, 
                      col_first=1, 
                      col_last=df.shape[1])

# %%
du_df = distribution_uniformity(df=df.pipe(apply_scaling), 
                      win=7, 
                      xmin=0, 
                      xmax=1, 
                      col_first=1, 
                      col_last=df.shape[1])

# %%
cr_df = complexity_resonance(fi_df, du_df)

# %%
_ = complexity_resonance_diagram(cr_df, figsize=(20, 3))

# %%
cumulative_complexity_peaks_df, significant_peaks_df = cumulative_complexity_peaks(df = cr_df,
                            significant_level_item = 0.05,
                            significant_level_time = 0.05)

# %%
_ = cumulative_complexity_peaks_plot(cumulative_complexity_peaks_df=cumulative_complexity_peaks_df, 
                                     significant_peaks_df=significant_peaks_df,
                                     figsize=(20, 3))

# %% [markdown]
# ## Dates of interest

# %%
significant_peaks_df[significant_peaks_df["Significant CCPs"]==1]
# Out:
#             Significant CCPs
# 2021-04-12               1.0
# 2021-05-31               1.0
# 2021-06-01               1.0
# 2021-06-02               1.0
# 2021-06-03               1.0
# 2021-06-04               1.0
# 2021-06-05               1.0

# %%
_ = plt.figure(figsize=(20, 5))
_ = sns.lineplot(data=df
 .pipe(apply_scaling)
 .reset_index()
 .melt(id_vars="date"),
                 x="date",
                 y="value",
                 hue="variable"
)
_ = sns.scatterplot(data=df
 .pipe(apply_scaling)
 .reset_index()
 .melt(id_vars="date"),
                 x="date",
                 y="value",
                 hue="variable"
)
for date in significant_peaks_df[significant_peaks_df["Significant CCPs"]==1].index.tolist():
    _ = plt.axvline(date, c="black", ls="--")

# %%
for col in df.columns.tolist():
    _ = plt.figure(figsize=(20, 5))
    for date in significant_peaks_df[significant_peaks_df["Significant CCPs"]==1].index.tolist():
        _ = plt.axvline(date, c="red", ls="--")
    _ = sns.lineplot(data=df
     .reset_index(),
                     x="date",
                     y=col,
    )
    _ = sns.scatterplot(data=df
     .reset_index(),
                     x="date",
                     y=col,
    )
